# %% [markdown]
# # Physics 494/594
# ## Welcome to Introduction to Machine Learning for Scientists
#
# We begin by using the iPython `%load` magic to import some libraries and set some styling (to make our plots look nice) from `/.include/header.py`

# %%
# %load ./include/header.py
import numpy as np
import matplotlib.pyplot as plt
import sys
from tqdm import trange,tqdm
sys.path.append('./include')
import ml4s
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
#plt.style.use('./include/notebook.mplstyle')
np.set_printoptions(linewidth=120)
#ml4s.set_css_style('./include/bootstrap.css')
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']

# %%
# !pip3 install ml4s
# Out:
# Collecting ml4s
#   Downloading ml4s-1.0.0.tar.gz (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.4/250.4 kB 6.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from ml4s) (1.26.4)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.11/dist-packages (from ml4s) (1.13.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from ml4s) (24.2)
# Building wheels for collected packages: ml4s
#   Building wheel for ml4s (setup.py) ... done
#   Created wheel for ml4s: filename=ml4s-1.0.0-py3-none-any.whl size=259487 sha256=d33b750aa41c72432a211db3493e04caac04b168d6ee3ba59565a10638795961
#   Stored in directory: /root/.cache/pip/wheels/bd/e5/41/5e46b1fff30b171950e060c964a5d61572d3fe8ac1c1f0618f
# Successfully built ml4s
# Installing collected packages: ml4s
# Successfully installed ml4s-1.0.0
